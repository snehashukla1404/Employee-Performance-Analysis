# %% [markdown]
# Importing important funtions

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import array as arr
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
from collections import Counter

# %% [markdown]
# Reading file and displaying head containing heading of columns

# %%
df = pd.read_excel('/content/drive/MyDrive/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')
df.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %% [markdown]
# Describing all the numerical data.

# %%
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# Checking the data types of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %% [markdown]
# Visualising the important data

# %%
cat_df=df.select_dtypes(include='object')
i=2
for i in cat_df:
    plt.figure(figsize=(30, 30))
    sns.catplot(data=df,x=i,kind='count')

# %%
sns.countplot(data = df, x = 'EmpWorkLifeBalance')
plt.show()
sns.countplot(data = df, x = 'EmpEducationLevel')
plt.show()

# %% [markdown]
# Checking if data contains any null value

# %%
df.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %% [markdown]
# Dropping employee number beacause of no use in analysis

# %%
df = df.drop('EmpNumber',axis=1)
df.head()
# Out:
#    Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0   32   Male           Marketing        Single            Sales
# 1   47   Male           Marketing        Single            Sales
# 2   40   Male       Life Sciences       Married            Sales
# 3   41   Male     Human Resources      Divorced  Human Resources
# 4   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# 0                  3                           4  ...
# 1                  4                           4  ...
# ...

# %% [markdown]
# Checking mean values of different factors according to different factors

# %%
gb = df.groupby("Gender").agg({"EmpHourlyRate" : 'mean',"EmpLastSalaryHikePercent" : 'mean',"EmpWorkLifeBalance" : 'mean',"DistanceFromHome" : 'mean',"TotalWorkExperienceInYears" : 'mean',"PerformanceRating" : 'mean'})
print(gb)
# Out:
#         EmpHourlyRate  EmpLastSalaryHikePercent  EmpWorkLifeBalance  \
# Gender
# Female      65.926316                 15.246316            2.730526
# Male        66.017931                 15.206897            2.753103
#
#         DistanceFromHome  TotalWorkExperienceInYears  PerformanceRating
# Gender
# Female          9.181053                   11.917895           2.949474
# Male            9.155862                   10.944828           2.947586

# %%
gp = df.groupby("EducationBackground").agg({"EmpHourlyRate" : 'mean',"EmpLastSalaryHikePercent" : 'mean',"DistanceFromHome" : 'mean',"TotalWorkExperienceInYears" : 'mean',"PerformanceRating" : 'mean'})
print(gp)
# Out:
#                      EmpHourlyRate  EmpLastSalaryHikePercent  \
# EducationBackground
# Human Resources          62.571429                 14.666667
# Life Sciences            67.018293                 15.292683
# Marketing                66.248175                 15.116788
# Medical                  65.304688                 15.208333
# Other                    61.257576                 15.681818
# Technical Degree         66.950000                 14.890000
#
#                      DistanceFromHome  TotalWorkExperienceInYears  \
# EducationBackground
# Human Resources              9.619048                   11.666667
# Life Sciences                8.991870                   11.247967
# Marketing                   10.131387                   12.029197
# Medical                      9.283854                   11.692708
# Other                        8.954545                    9.848485
# Technical Degree             8.290000                   10.290000
#
# ...

# %%
gj = df.groupby("EmpJobRole").agg({"EmpHourlyRate" : 'mean',"EmpLastSalaryHikePercent" : 'mean',"DistanceFromHome" : 'mean',"TotalWorkExperienceInYears" : 'mean',"PerformanceRating" : 'mean'})
print(gj)
# Out:
#                            EmpHourlyRate  EmpLastSalaryHikePercent  \
# EmpJobRole
# Business Analyst               63.312500                 15.437500
# Data Scientist                 62.250000                 16.450000
# Delivery Manager               57.666667                 14.583333
# Developer                      66.635593                 15.169492
# Finance Manager                66.693878                 15.367347
# Healthcare Representative      65.272727                 14.757576
# Human Resources                65.000000                 14.866667
# Laboratory Technician          68.578125                 14.781250
# Manager                        68.666667                 15.392157
# Manager R&D                    68.244681                 15.468085
# Manufacturing Director         67.727273                 15.272727
# Research Director              69.000000                 15.105263
# Research Scientist             65.311688                 15.688312
# ...

# %%
gd = df.groupby("EmpDepartment").agg({"EmpHourlyRate" : 'mean',"EmpLastSalaryHikePercent" : 'mean',"DistanceFromHome" : 'mean',"TotalWorkExperienceInYears" : 'mean',"PerformanceRating" : 'mean'})
print(gd)
# Out:
#                         EmpHourlyRate  EmpLastSalaryHikePercent  \
# EmpDepartment
# Data Science                62.250000                 16.450000
# Development                 65.828255                 15.204986
# Finance                     66.693878                 15.367347
# Human Resources             65.703704                 14.740741
# Research & Development      67.023324                 15.300292
# Sales                       65.319035                 15.152815
#
#                         DistanceFromHome  TotalWorkExperienceInYears  \
# EmpDepartment
# Data Science                    9.650000                   12.100000
# Development                     8.789474                   11.008310
# Finance                        11.877551                   10.877551
# Human Resources                 8.666667                   11.851852
# Research & Development          9.230321                   11.746356
# Sales                           9.160858                   11.201072
# ...

# %%
gd = df.groupby("Attrition").agg({"EmpHourlyRate" : 'mean',"EmpLastSalaryHikePercent" : 'mean',"DistanceFromHome" : 'mean',"TotalWorkExperienceInYears" : 'mean',"PerformanceRating" : 'mean'})
print(gd)
# Out:
#            EmpHourlyRate  EmpLastSalaryHikePercent  DistanceFromHome  \
# Attrition
# No             66.203523                 15.236791          8.950098
# Yes            64.707865                 15.140449         10.404494
#
#            TotalWorkExperienceInYears  PerformanceRating
# Attrition
# No                          11.932485           2.956947
# Yes                          7.870787           2.898876

# %%
gm = df.groupby("MaritalStatus").agg({"EmpHourlyRate" : 'mean',"EmpJobSatisfaction" : 'mean',"DistanceFromHome" : 'mean',"TotalWorkExperienceInYears" : 'mean',"PerformanceRating" : 'mean'})
print(gm)
# Out:
#                EmpHourlyRate  EmpJobSatisfaction  DistanceFromHome  \
# MaritalStatus
# Divorced           66.022388            2.641791          9.186567
# Married            66.379562            2.742701          9.395985
# Single             65.385417            2.781250          8.822917
#
#                TotalWorkExperienceInYears  PerformanceRating
# MaritalStatus
# Divorced                        12.119403           2.958955
# Married                         11.724453           2.917883
# Single                          10.216146           2.984375

# %%
mt = df.iloc[:,[3,6]].copy()
mt_per = mt.copy()

# %%
mt_per.groupby(by='MaritalStatus')['BusinessTravelFrequency'].value_counts()
# Out:
# MaritalStatus  BusinessTravelFrequency
# Divorced       Travel_Rarely              175
#                Travel_Frequently           53
#                Non-Travel                  40
# Married        Travel_Rarely              407
#                Travel_Frequently           92
#                Non-Travel                  49
# Single         Travel_Rarely              264
#                Travel_Frequently           77
#                Non-Travel                  43
# Name: BusinessTravelFrequency, dtype: int64

# %%
dept = df.iloc[:,[4,26]].copy()
dept_per = dept.copy()

# %%
# Analyze each department separately
dept_per.groupby(by='EmpDepartment')['PerformanceRating'].value_counts()
# Out:
# EmpDepartment           PerformanceRating
# Data Science            3                     17
#                         4                      2
#                         2                      1
# Development             3                    304
#                         4                     44
#                         2                     13
# Finance                 3                     30
#                         2                     15
#                         4                      4
# Human Resources         3                     38
#                         2                     10
#                         4                      6
# Research & Development  3                    234
#                         2                     68
#                         4                     41
# Sales                   3                    251
#                         2                     87
#                         4                     35
# ...

# %%
department = pd.get_dummies(dept_per['EmpDepartment'])
performance = pd.DataFrame(dept_per['PerformanceRating'])
dept_rating = pd.concat([department,performance],axis=1)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.barplot(x=dept_rating['PerformanceRating'],y=dept_rating['Sales'])
plt.subplot(2,3,2)
sns.barplot(x=dept_rating['PerformanceRating'],y=dept_rating['Development'])
plt.subplot(2,3,3)
sns.barplot(x=dept_rating['PerformanceRating'],y=dept_rating['Research & Development'])
plt.subplot(2,3,4)
sns.barplot(x=dept_rating['PerformanceRating'],y=dept_rating['Human Resources'])
plt.subplot(2,3,5)
sns.barplot(x=dept_rating['PerformanceRating'],y=dept_rating['Finance'])
plt.subplot(2,3,6)
sns.barplot(x=dept_rating['PerformanceRating'],y=dept_rating['Data Science'])
plt.show()

# %% [markdown]
# Scatter plot between age and employee hourly rate

# %%
x=df.Age
y=df.EmpHourlyRate
c = Counter(zip(x,y))
# create a list of the sizes, here multiplied by 10 for scale
s = [10*c[(xx,yy)] for xx,yy in zip(x,y)]

# plot it
plt.scatter(x, y, s=s)
plt.show()

# %% [markdown]
# Linear regression between work experience and last salary hike

# %%
import array
x=df.Age
y=df.PerformanceRating
model = LinearRegression()
c = Counter(zip(x,y))
# create a list of the sizes, here multiplied by 10 for scale
s = [10*c[(xx,yy)] for xx,yy in zip(x,y)]

# plot it
plt.scatter(x, y, s=s)

plt.show()

# %%
df.corr()
# Out:
# <ipython-input-23-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                    Age  DistanceFromHome  EmpEducationLevel  \
# Age                           1.000000          0.020937           0.207313
# DistanceFromHome              0.020937          1.000000           0.045856
# EmpEducationLevel             0.207313          0.045856           1.000000
# EmpEnvironmentSatisfaction    0.013814         -0.017719          -0.037103
# EmpHourlyRate                 0.062867          0.013730           0.014095
# EmpJobInvolvement             0.027216          0.003231           0.027544
# EmpJobLevel                   0.509139          0.017270           0.100734
# EmpJobSatisfaction           -0.002436         -0.003036           0.000357
# ...

# %% [markdown]
# Logistic Regression Model

# %%
# Here we have selected only the important columns
y = df.PerformanceRating
#X = data.iloc[:,0:-1]  All predictors were selected it resulted in dropping of accuracy.
X = df.iloc[:,[9,16,20,21,22,23,24]] # Taking only variables with correlation coeffecient greater than 0.1
X.head()
# Out:
#    EmpEnvironmentSatisfaction  EmpLastSalaryHikePercent  EmpWorkLifeBalance  \
# 0                           4                        12                   2
# 1                           4                        12                   3
# 2                           4                        21                   3
# 3                           2                        15                   2
# 4                           1                        14                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     8
# ...

# %%
# Splitting into train and test for calculating the accuracy
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=10)

# %%
# Standardization technique is used
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (840, 7)

# %%
X_test.shape
# Out:
# (360, 7)

# %%
# Training the model
from sklearn.linear_model import LogisticRegression
model_logr = LogisticRegression()
model_logr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
# Predicting the model
y_predict_log = model_logr.predict(X_test)

# %%
print(accuracy_score(y_test,y_predict_log))
print(classification_report(y_test,y_predict_log))
# Out:
# 0.8027777777777778
#               precision    recall  f1-score   support
#
#            2       0.61      0.27      0.37        63
#            3       0.82      0.95      0.88       264
#            4       0.79      0.67      0.72        33
#
#     accuracy                           0.80       360
#    macro avg       0.74      0.63      0.66       360
# weighted avg       0.78      0.80      0.78       360

# %% [markdown]
# 80.278% accuracy
